# %%
import GetOldTweets3 as got
import requests
import json 
import pandas as pd
from time import sleep
import time
import tweepy

# %%
hou_traffic_accounts = ['houstontranstar', 'us290nw_traffic', 'TxDOTHouston', 'TotalTrafficHOU', 'METROHouAlerts']
hou_public_safety_accounts = ['HoustonOEM', 'ReadyHarris', 'HCSOTexas', 'houstonpolice', 'HoustonFire']
hou_weather_accounts = ['NWSHouston', 'KHOUweather', 'abc13weather', 'KPRC2WEATHER']

# %%
keywords = ['close']

# %%
# perform two pulls train and test
# one with key words and one without

# %%
t0 = time.time()

keywords = ['closed']
username = []
text = []
date = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2019-01-01").setUntil("2019-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username.append(tweet.username)
            text.append(tweet.text)
            date.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 41
# Total tweets scraped: 0
# Total tweets scraped: 189
# Total tweets scraped: 991
# Total tweets scraped: 52
# Seconds to execute: 56.338459730148315

# %%
train_tweets_2019 = pd.DataFrame({'username': username,
                                'tweet': text,
                                'date_posted': date})

# %%
train_tweets
# Out:
#              username                                              tweet  \
# 0     houstontranstar  CONSTRUCTION ALERT The I-610 West Loop NB and ...
# 1     houstontranstar  ROAD CLOSURE REMINDER: Closed until Feb. 2020 ...
# 2     houstontranstar  Heads up! IH-610 South Loop (EB) frontage road...
# 3     houstontranstar  WEEKEND ROAD CLOSURE: @TxDOTHouston crews will...
# 4     houstontranstar  Grand Parkway North westbound @Shaw Rd. (Accid...
# ...               ...                                                ...
# 1268   METROHouAlerts  Due to debris removal, the Milam St entrance o...
# 1269   METROHouAlerts         It was briefly closed, but is open now. ^B
# 1270   METROHouAlerts  Expect significant delays into downtown due to...
# 1271   METROHouAlerts  UPDATE: The Northwest Fwy HOV lane remains clo...
# 1272   METROHouAlerts  UPDATE: The Northwest Fwy HOV lane is closed a...
#
#                    date_posted
# 0    2019-11-08 21:26:25+00:00
# 1    2019-11-04 14:57:09+00:00
# 2    2019-10-18 13:56:50+00:00
# 3    2019-08-15 13:46:18+00:00
# 4    2019-08-12 19:40:37+00:00
# ...                        ...
# 1268 2019-02-26 19:23:40+00:00
# 1269 2019-02-07 12:32:08+00:00
# 1270 2019-02-07 12:13:42+00:00
# 1271 2019-01-03 00:42:22+00:00
# 1272 2019-01-03 00:02:34+00:00
#
# [1273 rows x 3 columns]

# %%
t0 = time.time()

keywords = ['closed']
username = []
text = []
date = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2019-01-01").setUntil("2019-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username.append(tweet.username)
            text.append(tweet.text)
            date.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 9
# Total tweets scraped: 9
# Total tweets scraped: 10
# Total tweets scraped: 72
# Total tweets scraped: 1
# Seconds to execute: 12.520065069198608

# %%
train_safety_tweets_2019 = train_tweets_2019 = pd.DataFrame({'username': username,
                                'tweet': text,
                                'date_posted': date})

train_safety_tweets_2019
# Out:
#           username                                              tweet  \
# 0       HoustonOEM  Heads up commuters: haz mat cleanup crews are ...
# 1       HoustonOEM   Heads up for your afternoon commute : several...
# 2       HoustonOEM  REMINDER: The Brazos Bridge on US 59 over Smit...
# 3       HoustonOEM  .@HoustonOEM is returning to Level IV – Normal...
# 4       HoustonOEM  Don't forget: Downtown streets will be closed ...
# ..             ...                                                ...
# 96   houstonpolice  610 West Loop (northbound) @Evergreen, acciden...
# 97   houstonpolice  I-45 North (outbound) @Airline, a five vehicle...
# 98   houstonpolice  Adult female deceased at the scene. Initial re...
# 99   houstonpolice  IH-45 (southbound) @Scott, all lanes closed du...
# 100    HoustonFire  UNDER EXTREME HEAT WARNING Find air conditioni...
#
#                   date_posted
# 0   2019-11-18 20:20:15+00:00
# 1   2019-09-12 21:03:22+00:00
# 2   2019-07-08 01:08:36+00:00
# 3   2019-05-11 19:35:44+00:00
# 4   2019-02-23 14:16:08+00:00
# ..                        ...
# 96  2019-01-18 12:20:46+00:00
# 97  2019-01-15 05:52:04+00:00
# 98  2019-01-08 07:50:40+00:00
# 99  2019-01-08 07:41:58+00:00
# 100 2019-07-07 03:06:52+00:00
#
# [101 rows x 3 columns]

# %%
train_tweets_2019 = pd.concat([train_tweets, train_safety_tweets_2019])

train_tweets_2019
# Out:
#             username                                              tweet  \
# 0    houstontranstar  CONSTRUCTION ALERT The I-610 West Loop NB and ...
# 1    houstontranstar  ROAD CLOSURE REMINDER: Closed until Feb. 2020 ...
# 2    houstontranstar  Heads up! IH-610 South Loop (EB) frontage road...
# 3    houstontranstar  WEEKEND ROAD CLOSURE: @TxDOTHouston crews will...
# 4    houstontranstar  Grand Parkway North westbound @Shaw Rd. (Accid...
# ..               ...                                                ...
# 96     houstonpolice  610 West Loop (northbound) @Evergreen, acciden...
# 97     houstonpolice  I-45 North (outbound) @Airline, a five vehicle...
# 98     houstonpolice  Adult female deceased at the scene. Initial re...
# 99     houstonpolice  IH-45 (southbound) @Scott, all lanes closed du...
# 100      HoustonFire  UNDER EXTREME HEAT WARNING Find air conditioni...
#
#                   date_posted
# 0   2019-11-08 21:26:25+00:00
# 1   2019-11-04 14:57:09+00:00
# 2   2019-10-18 13:56:50+00:00
# 3   2019-08-15 13:46:18+00:00
# 4   2019-08-12 19:40:37+00:00
# ..                        ...
# 96  2019-01-18 12:20:46+00:00
# 97  2019-01-15 05:52:04+00:00
# 98  2019-01-08 07:50:40+00:00
# 99  2019-01-08 07:41:58+00:00
# 100 2019-07-07 03:06:52+00:00
#
# [1374 rows x 3 columns]

# %% [markdown]
# # 2018 training data

# %%
t0 = time.time()

keywords = ['closed']
username_traffic_2018 = []
text_traffic_2018 = []
date_traffic_2018 = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2018-01-01").setUntil("2018-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_traffic_2018.append(tweet.username)
            text_traffic_2018.append(tweet.text)
            date_traffic_2018.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 5
# Total tweets scraped: 0
# Total tweets scraped: 101
# Total tweets scraped: 1480
# Total tweets scraped: 92
# Seconds to execute: 61.177107095718384

# %%
train_traffic_tweets_2018 = pd.DataFrame({'username': username_traffic_2018,
                                'tweet': text_traffic_2018,
                                'date_posted': date_traffic_2018})

train_traffic_tweets_2018
# Out:
#              username                                              tweet  \
# 0     houstontranstar  Main lanes still closed on US-290 Eastbound at...
# 1     houstontranstar  REMINDER: All four northbound lanes of Shepher...
# 2     houstontranstar  HEADS UP #Houston Drivers: Effective immediate...
# 3     houstontranstar  Hi, Angie! Looks like it may be closed until 5...
# 4     houstontranstar  This Incident will be worked as a hazmat situa...
# ...               ...                                                ...
# 1673   METROHouAlerts  SERVICE WILL BE SUSPENDED on the 44, 85, 86 & ...
# 1674   METROHouAlerts  FYI: The METRO RideStores at 1900 Main and 100...
# 1675   METROHouAlerts  Ice is being reported on some roads. We just c...
# 1676   METROHouAlerts  Due to current road conditions, ALL HOT/HOV la...
# 1677   METROHouAlerts  A fuel spill on Hwy 290 near Fairbanks is caus...
#
#                    date_posted
# 0    2018-12-30 00:25:52+00:00
# 1    2018-12-21 22:23:25+00:00
# 2    2018-12-21 20:10:25+00:00
# 3    2018-10-18 13:58:41+00:00
# 4    2018-01-16 00:01:23+00:00
# ...                        ...
# 1673 2018-01-16 19:00:13+00:00
# 1674 2018-01-16 18:18:52+00:00
# 1675 2018-01-16 13:39:28+00:00
# 1676 2018-01-16 13:37:40+00:00
# 1677 2018-01-09 22:54:48+00:00
#
# [1678 rows x 3 columns]

# %%
t0 = time.time()

keywords = ['closed']
username_safety_2018 = []
text_safety_2018 = []
date_safety_2018 = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2018-01-01").setUntil("2018-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_safety_2018.append(tweet.username)
            text_safety_2018.append(tweet.text)
            date_safety_2018.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 14
# Total tweets scraped: 6
# Total tweets scraped: 95
# Total tweets scraped: 53
# Total tweets scraped: 1
# Seconds to execute: 9.026185989379883

# %%
train_safety_tweets_2018 = pd.DataFrame({'username': username_safety_2018,
                                'tweet': text_safety_2018,
                                'date_posted': date_safety_2018})

train_safety_tweets_2018
# Out:
#           username                                              tweet  \
# 0       HoustonOEM  UPDATE: 45 North Freeway exit ramp at Houston ...
# 1       HoustonOEM  UPDATE: Travis at Commerce and Milam at Commer...
# 2       HoustonOEM  Check with @houstontranstar for updates on IH-...
# 3       HoustonOEM  Another holiday in Houston and you know what t...
# 4       HoustonOEM  .@FEMA Disaster Recovery Centers are closed ag...
# ..             ...                                                ...
# 164  houstonpolice  IH-59 Eastex Fwy S/B @3700 block closed all la...
# 165  houstonpolice  This stretch of the SW Fwy inbound has been cl...
# 166  houstonpolice  Units have I-10 W/B, I-10 E/B, & Hwy 90 W/B ra...
# 167  houstonpolice  I-45 North (southbound) @North Street, acciden...
# 168    HoustonFire  Our weather is better today, it's a good day t...
#
#                   date_posted
# 0   2018-12-08 07:29:26+00:00
# 1   2018-12-08 06:07:55+00:00
# 2   2018-10-16 20:21:51+00:00
# 3   2018-09-02 16:15:10+00:00
# 4   2018-01-17 15:23:39+00:00
# ..                        ...
# 164 2018-01-17 11:20:35+00:00
# 165 2018-01-17 10:37:12+00:00
# 166 2018-01-16 05:49:22+00:00
# 167 2018-01-12 17:07:22+00:00
# 168 2018-01-04 20:16:48+00:00
#
# [169 rows x 3 columns]

# %%
train_tweets_2018 = pd.concat([train_traffic_tweets_2018, train_safety_tweets_2018])

# %% [markdown]
# # 2017 Training Data

# %%
t0 = time.time()

keywords = ['closed']
username_traffic_2017 = []
text_traffic_2017 = []
date_traffic_2017 = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-01-01").setUntil("2017-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_traffic_2017.append(tweet.username)
            text_traffic_2017.append(tweet.text)
            date_traffic_2017.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 0
# Total tweets scraped: 0
# Total tweets scraped: 80
# Total tweets scraped: 1973
# Total tweets scraped: 77
# Seconds to execute: 87.72192883491516

# %%
train_traffic_tweets_2017 = pd.DataFrame({'username': username_traffic_2017,
                                'tweet': text_traffic_2017,
                                'date_posted': date_traffic_2017})

train_traffic_tweets_2017
# Out:
#             username                                              tweet  \
# 0       TxDOTHouston  If you are heading to @SugarLandtxgov and beyo...
# 1       TxDOTHouston  Due to bridge repairs, TxDOT has closed two al...
# 2       TxDOTHouston  Good news. All mainlanes of I-45 N Frwy NB bet...
# 3       TxDOTHouston  I-45 Northbound direct connector project conti...
# 4       TxDOTHouston  Two incident on I-10 Katy Frwy are significant...
# ...              ...                                                ...
# 2125  METROHouAlerts  The 217 is operating, but HOV lanes are closed...
# 2126  METROHouAlerts  Also - the HOV lanes are closed so the 102 is ...
# 2127  METROHouAlerts       All HOV Lanes remain closed at this time. ^A
# 2128  METROHouAlerts                          Yes the 290 is closed. ^A
# 2129  METROHouAlerts  #TurnAroundDontDrown: Expect delays on bus rou...
#
#                    date_posted
# 0    2017-12-13 23:22:50+00:00
# 1    2017-12-13 01:35:30+00:00
# 2    2017-12-04 02:46:13+00:00
# 3    2017-12-01 14:49:35+00:00
# 4    2017-11-28 22:18:29+00:00
# ...                        ...
# 2125 2017-01-18 13:35:51+00:00
# 2126 2017-01-18 13:33:52+00:00
# 2127 2017-01-18 12:19:12+00:00
# 2128 2017-01-18 12:04:58+00:00
# 2129 2017-01-18 11:09:24+00:00
#
# [2130 rows x 3 columns]

# %%
t0 = time.time()

keywords = ['closed']
username_safety_2017 = []
text_safety_2017 = []
date_safety_2017 = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-01-01").setUntil("2017-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_safety_2017.append(tweet.username)
            text_safety_2017.append(tweet.text)
            date_safety_2017.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 18
# Total tweets scraped: 21
# Total tweets scraped: 12
# Total tweets scraped: 65
# Total tweets scraped: 2
# Seconds to execute: 7.481235027313232

# %%
train_safety_tweets_2017 = pd.DataFrame({'username': username_safety_2017,
                                'tweet': text_safety_2017,
                                'date_posted': date_safety_2017})

train_safety_tweets_2017
# Out:
#           username                                              tweet  \
# 0       HoustonOEM  Access road on SB I-45 after Parker is closed....
# 1       HoustonOEM  Eastbound Pinemont after TC Jester is closed d...
# 2       HoustonOEM  TRAFFIC ADVISORY | I-10 Westbound at IH-610 We...
# 3       HoustonOEM  .@FEMA Disaster Recovery Centers will be close...
# 4       HoustonOEM  Memorial Drive Inbound is closed @Houston Ave....
# ..             ...                                                ...
# 113  houstonpolice  IH-45 GULF Northbound At SCOTT ST - CLOSED FOR...
# 114  houstonpolice  HPD investigating fatal roll-over accident at ...
# 115  houstonpolice  Inbound lanes of 45 North Fwy closed at I-10 d...
# 116    HoustonFire  Ellington Field is under evacuation after an F...
# 117    HoustonFire  HFD on scene of Hi-rise incident at 2000 W Loo...
#
#                   date_posted
# 0   2017-12-15 20:14:49+00:00
# 1   2017-11-28 22:31:01+00:00
# 2   2017-11-28 20:03:55+00:00
# 3   2017-11-17 16:45:34+00:00
# 4   2017-11-03 18:23:23+00:00
# ..                        ...
# 113 2017-02-21 21:03:49+00:00
# 114 2017-02-01 07:57:06+00:00
# 115 2017-01-17 16:48:59+00:00
# 116 2017-06-21 17:34:17+00:00
# 117 2017-04-02 17:08:36+00:00
#
# [118 rows x 3 columns]

# %%
train_tweets_2017 = pd.concat([train_traffic_tweets_2017, train_safety_tweets_2017])

# %% [markdown]
# # all training data

# %%
train_tweets = pd.concat([train_tweets_2017, train_tweets_2018, train_tweets_2019])

train_tweets
# Out:
#           username                                              tweet  \
# 0     TxDOTHouston  If you are heading to @SugarLandtxgov and beyo...
# 1     TxDOTHouston  Due to bridge repairs, TxDOT has closed two al...
# 2     TxDOTHouston  Good news. All mainlanes of I-45 N Frwy NB bet...
# 3     TxDOTHouston  I-45 Northbound direct connector project conti...
# 4     TxDOTHouston  Two incident on I-10 Katy Frwy are significant...
# ..             ...                                                ...
# 96   houstonpolice  610 West Loop (northbound) @Evergreen, acciden...
# 97   houstonpolice  I-45 North (outbound) @Airline, a five vehicle...
# 98   houstonpolice  Adult female deceased at the scene. Initial re...
# 99   houstonpolice  IH-45 (southbound) @Scott, all lanes closed du...
# 100    HoustonFire  UNDER EXTREME HEAT WARNING Find air conditioni...
#
#                   date_posted
# 0   2017-12-13 23:22:50+00:00
# 1   2017-12-13 01:35:30+00:00
# 2   2017-12-04 02:46:13+00:00
# 3   2017-12-01 14:49:35+00:00
# 4   2017-11-28 22:18:29+00:00
# ..                        ...
# 96  2019-01-18 12:20:46+00:00
# 97  2019-01-15 05:52:04+00:00
# 98  2019-01-08 07:50:40+00:00
# 99  2019-01-08 07:41:58+00:00
# 100 2019-07-07 03:06:52+00:00
#
# [5469 rows x 3 columns]

# %% [markdown]
# # obtaining 'test' data without a keyword search for 'closed'

# %%
t0 = time.time()

keywords = ['']
username_traffic_2019 = []
text_traffic_2019 = []
date_traffic_2019 = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2019-01-01").setUntil("2019-12-31").setQuerySearch(keyword).setMaxTweets(1000)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_traffic_2019.append(tweet.username)
            text_traffic_2019.append(tweet.text)
            date_traffic_2019.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 762
# Total tweets scraped: 1000
# Total tweets scraped: 1000
# Total tweets scraped: 1000
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Ametrohoualerts%20since%3A2019-01-01%20until%3A2019-12-31&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
test_traffic_2019 = pd.DataFrame({'username': username_traffic_2019,
                                'tweet': text_traffic_2019,
                                'date_posted': date_traffic_2019})

test_traffic_2019.head()
# Out:
#           username                                              tweet  \
# 0  houstontranstar  Heading home? Check out the @HoustonTranStar t...
# 1  houstontranstar         http://traffic.houstontranstar.org/layers/
# 2  houstontranstar         http://traffic.houstontranstar.org/layers/
# 3  houstontranstar  An important reminder to share with loved ones...
# 4  houstontranstar  The #NewYear is almost here! It’s a great time...
#
#                 date_posted
# 0 2019-12-30 22:47:00+00:00
# 1 2019-12-30 22:44:31+00:00
# 2 2019-12-30 22:32:44+00:00
# 3 2019-12-30 19:46:56+00:00
# 4 2019-12-30 19:24:44+00:00

# %%
t0 = time.time()

keywords = ['']
username_safety_2019 = []
text_safety_2019 = []
date_safety_2019 = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2019-01-01").setUntil("2019-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_safety_2019.append(tweet.username)
            text_safety_2019.append(tweet.text)
            date_safety_2019.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 489
# Total tweets scraped: 1299
# Total tweets scraped: 1083
# Total tweets scraped: 2503
# Total tweets scraped: 425
# Seconds to execute: 228.40476298332214

# %%
test_safety_2019 = pd.DataFrame({'username': username_safety_2019,
                                'tweet': text_safety_2019,
                                'date_posted': date_safety_2019})

test_safety_2019.head()
# Out:
#      username                                              tweet  \
# 0  HoustonOEM  ┏━━┓┏━━┓┏━━┓┏━━┓ ┗━┓┃┃┏┓┃┗━┓┃┃┏┓┃ ┏━┛┃┃┃┃┃┏━┛┃...
# 1  HoustonOEM  Thread: @houstonpolice is asking the public to...
# 2  HoustonOEM  #HappyHolidays from the entire Houston OEM tea...
# 3  HoustonOEM  Thread: most recent mercury spill update from ...
# 4  HoustonOEM  MERCURY SPILL UPDATE: Law enforcement continue...
#
#                 date_posted
# 0 2019-12-30 16:09:07+00:00
# 1 2019-12-23 14:44:13+00:00
# 2 2019-12-23 14:01:12+00:00
# 3 2019-12-19 22:25:19+00:00
# 4 2019-12-18 22:58:13+00:00

# %%
t0 = time.time()

keywords = ['']
username_weather_2019 = []
text_weather_2019 = []
date_weather_2019 = []
for keyword in keywords:
    for account in hou_weather_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2019-01-01").setUntil("2019-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_weather_2019.append(tweet.username)
            text_weather_2019.append(tweet.text)
            date_weather_2019.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 4914
# Total tweets scraped: 92
# Total tweets scraped: 1415
# Total tweets scraped: 773
# Seconds to execute: 273.251916885376

# %%
test_weather_2019 = pd.DataFrame({'username': username_weather_2019,
                                'tweet': text_weather_2019,
                                'date_posted': date_weather_2019})

test_weather_2019.head()
# Out:
#      username                                              tweet  \
# 0  NWSHouston  How open are you to changing your definition o...
# 1  NWSHouston  We're going crazy with the forecast, and doing...
# 2  NWSHouston  The first day of the new decade will be an ove...
# 3  NWSHouston  Start out 2020 with these New Year's Day Clima...
# 4  NWSHouston  Count down the end of the year with these New ...
#
#                 date_posted
# 0 2019-12-30 23:53:33+00:00
# 1 2019-12-30 23:44:36+00:00
# 2 2019-12-30 21:38:14+00:00
# 3 2019-12-30 18:27:05+00:00
# 4 2019-12-30 18:24:07+00:00

# %%
test_tweets_2019 = pd.concat([test_safety_2019, test_traffic_2019, test_weather_2019])
test_tweets_2019
# Out:
#           username                                              tweet  \
# 0       HoustonOEM  ┏━━┓┏━━┓┏━━┓┏━━┓ ┗━┓┃┃┏┓┃┗━┓┃┃┏┓┃ ┏━┛┃┃┃┃┃┏━┛┃...
# 1       HoustonOEM  Thread: @houstonpolice is asking the public to...
# 2       HoustonOEM  #HappyHolidays from the entire Houston OEM tea...
# 3       HoustonOEM  Thread: most recent mercury spill update from ...
# 4       HoustonOEM  MERCURY SPILL UPDATE: Law enforcement continue...
# ...            ...                                                ...
# 7189  KPRC2WEATHER  Weather Alert: Flood Warning for Liberty and P...
# 7190  KPRC2WEATHER  Weather Alert: Flood Warning for Walker County...
# 7191  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson Coun...
# 7192  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson and ...
# 7193  KPRC2WEATHER  Weather Alert: Flash Flood Watch for Walker, S...
#
#                    date_posted
# 0    2019-12-30 16:09:07+00:00
# 1    2019-12-23 14:44:13+00:00
# 2    2019-12-23 14:01:12+00:00
# 3    2019-12-19 22:25:19+00:00
# 4    2019-12-18 22:58:13+00:00
# ...                        ...
# 7189 2019-01-03 08:13:56+00:00
# 7190 2019-01-03 08:13:56+00:00
# 7191 2019-01-03 01:52:46+00:00
# 7192 2019-01-03 01:52:46+00:00
# 7193 2019-01-01 21:10:47+00:00
#
# [16755 rows x 3 columns]

# %% [markdown]
# ## 2018 test tweets

# %%
t0 = time.time()

keywords = ['']
username_traffic_2018 = []
text_traffic_2018 = []
date_traffic_2018 = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2018-01-01").setUntil("2018-12-31").setQuerySearch(keyword).setMaxTweets(5_000)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_traffic_2018.append(tweet.username)
            text_traffic_2018.append(tweet.text)
            date_traffic_2018.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 5000
# Total tweets scraped: 1679
# Total tweets scraped: 1286
# Total tweets scraped: 5000
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Ametrohoualerts%20since%3A2018-01-01%20until%3A2018-12-31&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
test_traffic_2018 = pd.DataFrame({'username': username_traffic_2018,
                                'tweet': text_traffic_2018,
                                'date_posted': date_traffic_2018})

test_traffic_2018.head()
# Out:
#           username                                              tweet  \
# 0  houstontranstar        https://traffic.houstontranstar.org/layers/
# 1  houstontranstar  Main lanes still closed on US-290 Eastbound at...
# 2  houstontranstar        https://traffic.houstontranstar.org/layers/
# 3  houstontranstar  A great reminder from @HCSOTexas! Do not drink...
# 4  houstontranstar  Check out the #HoustonTranStar website for an ...
#
#                 date_posted
# 0 2018-12-30 00:28:45+00:00
# 1 2018-12-30 00:25:52+00:00
# 2 2018-12-30 00:22:47+00:00
# 3 2018-12-28 21:34:40+00:00
# 4 2018-12-28 20:52:49+00:00

# %%
test_traffic_2018.shape
# Out:
# (12965, 3)

# %%
t0 = time.time()

keywords = ['']
username_safety_2018 = []
text_safety_2018 = []
date_safety_2018 = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2018-01-01").setUntil("2018-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_safety_2018.append(tweet.username)
            text_safety_2018.append(tweet.text)
            date_safety_2018.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 491
# Total tweets scraped: 1161
# Total tweets scraped: 1833
# Total tweets scraped: 2736
# Total tweets scraped: 769
# Seconds to execute: 270.61671710014343

# %%
test_safety_2018 = pd.DataFrame({'username': username_safety_2018,
                                'tweet': text_safety_2018,
                                'date_posted': date_safety_2018})

test_safety_2018.head()
# Out:
#      username                                              tweet  \
# 0  HoustonOEM  Residents in these areas should remain alert t...
# 1  HoustonOEM  UPDATE: @NWSHouston has cancelled this morning...
# 2  HoustonOEM  .@NWSHouston has issued a Tornado Watch until ...
# 3  HoustonOEM  Sign up for @AlertHouston at http://www.alerth...
# 4  HoustonOEM  Hi Paul, follow @CNPalerts for any updates dur...
#
#                 date_posted
# 0 2018-12-27 18:33:25+00:00
# 1 2018-12-27 13:25:05+00:00
# 2 2018-12-27 12:30:07+00:00
# 3 2018-12-27 10:03:18+00:00
# 4 2018-12-27 04:15:01+00:00

# %%
t0 = time.time()

keywords = ['']
username_weather_2018 = []
text_weather_2018 = []
date_weather_2018 = []
for keyword in keywords:
    for account in hou_weather_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2018-01-01").setUntil("2018-12-31").setQuerySearch(keyword)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_weather_2018.append(tweet.username)
            text_weather_2018.append(tweet.text)
            date_weather_2018.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 2884
# Total tweets scraped: 876
# Total tweets scraped: 337
# Total tweets scraped: 430
# Seconds to execute: 191.06329894065857

# %%
test_weather_2018 = pd.DataFrame({'username': username_weather_2018,
                                'tweet': text_weather_2018,
                                'date_posted': date_weather_2018})

test_weather_2018.head()
# Out:
#      username                                              tweet  \
# 0  NWSHouston  Flood Warning Extended until Monday Morningthe...
# 1  NWSHouston  The Flood Warning Continues for The Navasota R...
# 2  NWSHouston  The Flood Warning Continues for The West Fork ...
# 3  NWSHouston  The Flood Warning Continues for The East Fork ...
# 4  NWSHouston  The Flood Warning Continues for The Trinity Ri...
#
#                 date_posted
# 0 2018-12-30 16:16:44+00:00
# 1 2018-12-30 16:16:01+00:00
# 2 2018-12-30 16:15:19+00:00
# 3 2018-12-30 16:14:36+00:00
# 4 2018-12-30 16:13:53+00:00

# %%
test_tweets_2018 = pd.concat([test_safety_2018, test_traffic_2018, test_weather_2018])
test_tweets_2018
# Out:
#           username                                              tweet  \
# 0       HoustonOEM  Residents in these areas should remain alert t...
# 1       HoustonOEM  UPDATE: @NWSHouston has cancelled this morning...
# 2       HoustonOEM  .@NWSHouston has issued a Tornado Watch until ...
# 3       HoustonOEM  Sign up for @AlertHouston at http://www.alerth...
# 4       HoustonOEM  Hi Paul, follow @CNPalerts for any updates dur...
# ...            ...                                                ...
# 4522  KPRC2WEATHER  ICYMI- Last really icy morning today- we'll be...
# 4523  KPRC2WEATHER  Morning everyone!! Still cold this morning in ...
# 4524  KPRC2WEATHER  BRRR! Wind chill temperatures will make it fee...
# 4525  KPRC2WEATHER  How about a little sleet and some flurries in ...
# 4526  KPRC2WEATHER  Here's a snapshot of how cold it'll be ringing...
#
#                    date_posted
# 0    2018-12-27 18:33:25+00:00
# 1    2018-12-27 13:25:05+00:00
# 2    2018-12-27 12:30:07+00:00
# 3    2018-12-27 10:03:18+00:00
# 4    2018-12-27 04:15:01+00:00
# ...                        ...
# 4522 2018-01-04 13:11:34+00:00
# 4523 2018-01-04 11:14:40+00:00
# 4524 2018-01-01 22:56:14+00:00
# 4525 2018-01-01 02:48:46+00:00
# 4526 2018-01-01 01:10:47+00:00
#
# [24482 rows x 3 columns]

# %% [markdown]
# ## 2017 test tweets

# %%
t0 = time.time()

keywords = ['']
username_traffic_2017 = []
text_traffic_2017 = []
date_traffic_2017 = []
for keyword in keywords:
    for account in hou_traffic_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-01-01").setUntil("2017-12-31").setQuerySearch(keyword).setMaxTweets(2_500)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_traffic_2017.append(tweet.username)
            text_traffic_2017.append(tweet.text)
            date_traffic_2017.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 2500
# Total tweets scraped: 834
# Total tweets scraped: 1726
# Total tweets scraped: 2500
# Total tweets scraped: 2500
# Seconds to execute: 386.2205288410187

# %%
test_traffic_2017 = pd.DataFrame({'username': username_traffic_2017,
                                'tweet': text_traffic_2017,
                                'date_posted': date_traffic_2017})

test_traffic_2017
# Out:
#               username                                              tweet  \
# 0      houstontranstar  IH-45 GULF Northbound At GRIGGS RD - Stall - S...
# 1      houstontranstar  SH-225 Westbound At GOODYEAR - Accident - Stat...
# 2      houstontranstar  IH-10 KATY Westbound Before SH-6 - Accident - ...
# 3      houstontranstar  IH-610 NORTH LOOP Westbound At HARDY TOLL RD/S...
# 4      houstontranstar  IH-10 KATY Eastbound At SILBER RD - Road Debri...
# ...                ...                                                ...
# 10055   METROHouAlerts  The #METROBus160 route has resumed regular ser...
# 10056   METROHouAlerts  The #METROBus153 westbound route has resumed r...
# 10057   METROHouAlerts  #METROBus77 will continue along Homestead and ...
# 10058   METROHouAlerts  One bus on #METROBus88 S/B delayed at Airport/...
# 10059   METROHouAlerts  The #METROBus292 outbound route has resumed se...
#
#                     date_posted
# 0     2017-12-30 23:57:05+00:00
# 1     2017-12-30 23:51:05+00:00
# 2     2017-12-30 23:39:05+00:00
# 3     2017-12-30 23:27:05+00:00
# 4     2017-12-30 23:09:05+00:00
# ...                         ...
# 10055 2017-09-11 15:15:34+00:00
# 10056 2017-09-11 14:20:00+00:00
# 10057 2017-09-11 14:19:02+00:00
# 10058 2017-09-11 14:09:46+00:00
# 10059 2017-09-11 13:18:23+00:00
#
# [10060 rows x 3 columns]

# %%
t0 = time.time()

keywords = ['']
username_safety_2017 = []
text_safety_2017 = []
date_safety_2017 = []
for keyword in keywords:
    for account in hou_public_safety_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-01-01").setUntil("2017-12-31").setQuerySearch(keyword).setMaxTweets(2_500)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_safety_2017.append(tweet.username)
            text_safety_2017.append(tweet.text)
            date_safety_2017.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 1316
# Total tweets scraped: 1866
# Total tweets scraped: 1510
# Total tweets scraped: 2456
# Total tweets scraped: 572
# Seconds to execute: 298.6385910511017

# %%
test_safety_2017 = pd.DataFrame({'username': username_safety_2017,
                                'tweet': text_safety_2017,
                                'date_posted': date_safety_2017})

test_safety_2017
# Out:
#          username                                              tweet  \
# 0      HoustonOEM  Durante Clima Invernal , Recuerda proteger las...
# 1      HoustonOEM  During cold weather , remember to protect the ...
# 2      HoustonOEM  Also, while you can buy fireworks in the uninc...
# 3      HoustonOEM  As we expect temperatures to continue their de...
# 4      HoustonOEM  Dense Fog Advisory in effect until 10:00am. Sl...
# ...           ...                                                ...
# 7715  HoustonFire  @SylvesterTurner News Conference- thirty day c...
# 7716  HoustonFire  Congratulations to the Houston Fire Department...
# 7717  HoustonFire             18 members being promoted this morning
# 7718  HoustonFire  In 2016, HFD responded to 335,973 incidents (4...
# 7719  HoustonFire  Newsmakers for Jan. 1: New HFD chief, start of...
#
#                    date_posted
# 0    2017-12-30 18:01:00+00:00
# 1    2017-12-30 18:00:03+00:00
# 2    2017-12-29 20:43:42+00:00
# 3    2017-12-29 19:11:17+00:00
# 4    2017-12-19 12:15:30+00:00
# ...                        ...
# 7715 2017-01-05 16:07:39+00:00
# 7716 2017-01-04 16:52:18+00:00
# 7717 2017-01-04 16:04:36+00:00
# 7718 2017-01-03 17:18:08+00:00
# 7719 2017-01-03 16:51:40+00:00
#
# [7720 rows x 3 columns]

# %%
t0 = time.time()

keywords = ['']
username_weather_2017 = []
text_weather_2017 = []
date_weather_2017 = []
for keyword in keywords:
    for account in hou_weather_accounts:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-01-01").setUntil("2017-12-31").setQuerySearch(keyword).setMaxTweets(2_500)
        tweet_collection = got.manager.TweetManager.getTweets(tweetCriteria) 
        
        print(f"Total tweets scraped: {len(tweet_collection)}")
        for tweet in tweet_collection:
            username_weather_2017.append(tweet.username)
            text_weather_2017.append(tweet.text)
            date_weather_2017.append(tweet.date)
        
print(f'Seconds to execute:',(time.time() - t0))
# Out:
# Total tweets scraped: 2500
# Total tweets scraped: 2152
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%20from%3Aabc13weather%20since%3A2017-01-01%20until%3A2017-12-31&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
test_weather_2017 = pd.DataFrame({'username': username_weather_2017,
                                'tweet': text_weather_2017,
                                'date_posted': date_weather_2017})

test_weather_2017
# Out:
#          username                                              tweet  \
# 0      NWSHouston  This here's some good advice. And if you're pl...
# 1      NWSHouston  Today will be the day to start wrapping pipes ...
# 2      NWSHouston  As we head into the New Year holiday, a cold f...
# 3      NWSHouston  In general, no - though cold weather may requi...
# 4      NWSHouston  We're still several days off and evaluating ho...
# ...           ...                                                ...
# 4647  KHOUweather  I'll see you in under an hour on KHOU 11 News!...
# 4648  KHOUweather  2016 will end on a surplus in the rain dept. W...
# 4649  KHOUweather  As we close out 2016, here's a look a the hott...
# 4650  KHOUweather  Here's a look at the next 7 days: strong storm...
# 4651  KHOUweather  Downtown looking good on this last night of 20...
#
#                    date_posted
# 0    2017-12-30 14:36:22+00:00
# 1    2017-12-30 12:36:13+00:00
# 2    2017-12-29 22:02:12+00:00
# 3    2017-12-29 05:42:23+00:00
# 4    2017-12-29 05:39:52+00:00
# ...                        ...
# 4647 2017-01-01 03:06:09+00:00
# 4648 2017-01-01 02:52:32+00:00
# 4649 2017-01-01 02:41:50+00:00
# 4650 2017-01-01 00:37:14+00:00
# 4651 2017-01-01 00:07:33+00:00
#
# [4652 rows x 3 columns]

# %%
test_tweets_2017 = pd.concat([test_safety_2017, test_traffic_2017, test_weather_2017])
test_tweets_2017
# Out:
#          username                                              tweet  \
# 0      HoustonOEM  Durante Clima Invernal , Recuerda proteger las...
# 1      HoustonOEM  During cold weather , remember to protect the ...
# 2      HoustonOEM  Also, while you can buy fireworks in the uninc...
# 3      HoustonOEM  As we expect temperatures to continue their de...
# 4      HoustonOEM  Dense Fog Advisory in effect until 10:00am. Sl...
# ...           ...                                                ...
# 4647  KHOUweather  I'll see you in under an hour on KHOU 11 News!...
# 4648  KHOUweather  2016 will end on a surplus in the rain dept. W...
# 4649  KHOUweather  As we close out 2016, here's a look a the hott...
# 4650  KHOUweather  Here's a look at the next 7 days: strong storm...
# 4651  KHOUweather  Downtown looking good on this last night of 20...
#
#                    date_posted
# 0    2017-12-30 18:01:00+00:00
# 1    2017-12-30 18:00:03+00:00
# 2    2017-12-29 20:43:42+00:00
# 3    2017-12-29 19:11:17+00:00
# 4    2017-12-19 12:15:30+00:00
# ...                        ...
# 4647 2017-01-01 03:06:09+00:00
# 4648 2017-01-01 02:52:32+00:00
# 4649 2017-01-01 02:41:50+00:00
# 4650 2017-01-01 00:37:14+00:00
# 4651 2017-01-01 00:07:33+00:00
#
# [22432 rows x 3 columns]

# %% [markdown]
# ### building a combined test tweets dataframe

# %%
test_tweets = pd.concat([test_tweets_2017, test_tweets_2018, test_tweets_2019])

# %% [markdown]
# ## combining train tweets (keyword search for closure tweets) & test (no restrictions)

# %%
data = pd.concat([train_tweets, test_tweets])

# %%
data
# Out:
#           username                                              tweet  \
# 0     TxDOTHouston  If you are heading to @SugarLandtxgov and beyo...
# 1     TxDOTHouston  Due to bridge repairs, TxDOT has closed two al...
# 2     TxDOTHouston  Good news. All mainlanes of I-45 N Frwy NB bet...
# 3     TxDOTHouston  I-45 Northbound direct connector project conti...
# 4     TxDOTHouston  Two incident on I-10 Katy Frwy are significant...
# ...            ...                                                ...
# 7189  KPRC2WEATHER  Weather Alert: Flood Warning for Liberty and P...
# 7190  KPRC2WEATHER  Weather Alert: Flood Warning for Walker County...
# 7191  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson Coun...
# 7192  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson and ...
# 7193  KPRC2WEATHER  Weather Alert: Flash Flood Watch for Walker, S...
#
#                    date_posted
# 0    2017-12-13 23:22:50+00:00
# 1    2017-12-13 01:35:30+00:00
# 2    2017-12-04 02:46:13+00:00
# 3    2017-12-01 14:49:35+00:00
# 4    2017-11-28 22:18:29+00:00
# ...                        ...
# 7189 2019-01-03 08:13:56+00:00
# 7190 2019-01-03 08:13:56+00:00
# 7191 2019-01-03 01:52:46+00:00
# 7192 2019-01-03 01:52:46+00:00
# 7193 2019-01-01 21:10:47+00:00
#
# [69138 rows x 3 columns]

# %%
data.dtypes # reveals date_posted already in a datetime64 format
# Out:
# username                    object
# tweet                       object
# date_posted    datetime64[ns, UTC]
# dtype: object

# %%
import requests
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
import regex as re
from nltk.stem.porter import PorterStemmer
from bs4 import BeautifulSoup  
from sklearn.feature_extraction import stop_words
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nicolasavega/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nicolasavega/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# the below regex code replaces the links that being in http in our text
data['tweet'] = data.loc[:, 'tweet'].map(lambda row : re.sub(r'http\S+', '', row))
data['tweet'] = data.loc[:, 'tweet'].map(lambda row : re.sub(r'@\S+', '', row))

# %%
# code to remove hastages from tweets!
data['tweet'] = data.loc[:, 'tweet'].map(lambda row : re.sub(r'#', '', row))

# %%
data['tweet'].value_counts()
# Out:
#                                                                                                                                                473
# Good morning! Here's our 4am temperatures. In 25 minutes, I'll have your forecast update LIVE on KHOU 11 News.                                 279
# , Special Weather Statement.  txwx houwx bcswx                                                                                                 181
# Good morning! Here's your forecast from ABC13. Houston TXwx                                                                                    151
# The Flood Warning Continues for The Trinity River Near Moss Bluff until Further Notice Or until The Warning Is Canceled..  txwx houwx bcswx    145
#                                                                                                                                               ...
# Bella Vista  Suspect in Custody. K-9 Contact hounews CC8                                                                                         1
# Accident in the hov lane in SouthwestSide on I-69 SW Fwy HOV SB at Chimney Rock Rd, stop and go traffic back to TX-527 Spur traffic              1
# Accident, left lane blocked in Channelview on I-10 E Fwy Inbound after Federal traffic                                                           1
# Accident, right lane blocked in Northside on 610 N Lp WB at T.C. Jester, stop and go traffic back to The Hardy Toll Rd., delay of 20 mins        1
# Freeway open in Downtown on I-10 katy Fwy Inbound approaching I-45, stop and go traffic back to The W Lp, delay of 30 mins traffic               1
# Name: tweet, Length: 61254, dtype: int64

# %%
# list of leftover HTML characters to clean out with blanks
rem_chars = ['\n', '\ufeff', '>', '**', '\'ve', '#', '…']

# %%
for char in rem_chars:
    data['tweet'] = data.loc[:, 'tweet'].map(lambda text : text.replace(char, ' '))

# %%
data
# Out:
#           username                                              tweet  \
# 0     TxDOTHouston  If you are heading to  and beyond going SB on ...
# 1     TxDOTHouston  Due to bridge repairs, TxDOT has closed two al...
# 2     TxDOTHouston  Good news. All mainlanes of I-45 N Frwy NB bet...
# 3     TxDOTHouston  I-45 Northbound direct connector project conti...
# 4     TxDOTHouston  Two incident on I-10 Katy Frwy are significant...
# ...            ...                                                ...
# 7189  KPRC2WEATHER  Weather Alert: Flood Warning for Liberty and P...
# 7190  KPRC2WEATHER  Weather Alert: Flood Warning for Walker County .
# 7191  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson Coun...
# 7192  KPRC2WEATHER  Weather Alert: Flood Warning for Burleson and ...
# 7193  KPRC2WEATHER  Weather Alert: Flash Flood Watch for Walker, S...
#
#                    date_posted
# 0    2017-12-13 23:22:50+00:00
# 1    2017-12-13 01:35:30+00:00
# 2    2017-12-04 02:46:13+00:00
# 3    2017-12-01 14:49:35+00:00
# 4    2017-11-28 22:18:29+00:00
# ...                        ...
# 7189 2019-01-03 08:13:56+00:00
# 7190 2019-01-03 08:13:56+00:00
# 7191 2019-01-03 01:52:46+00:00
# 7192 2019-01-03 01:52:46+00:00
# 7193 2019-01-01 21:10:47+00:00
#
# [69138 rows x 3 columns]

# %% [markdown]
# # Build a mask to identify tweets that would indicate a road closure

# %%
mask_road = data['tweet'].str.contains('road', regex=False, case=False)
mask_rd = data['tweet'].str.contains('rd', regex=False, case=False)
mask_exit = data['tweet'].str.contains('exit', regex=False, case=False)
mask_street = data['tweet'].str.contains('street', regex=False, case=False)
mask_highway = data['tweet'].str.contains('highway', regex=False, case=False)
mask_hwy = data['tweet'].str.contains('hwy', regex=False, case=False)
mask_ramp = data['tweet'].str.contains('ramp', regex=False, case=False)
mask_st = data['tweet'].str.contains('st', regex=False, case=False)
mask_ave = data['tweet'].str.contains('ave', regex=False, case=False)
mask_lane = data['tweet'].str.contains('lane', regex=False, case=False)
mask_ln = data['tweet'].str.contains('ln', regex=False, case=False)
mask_drive = data['tweet'].str.contains('drive', regex=False, case=False)
mask_clos = data['tweet'].str.contains('clos', regex=False, case=False)
mask_close = data['tweet'].str.contains('close', regex=False, case=False) # ask J with 'close' should cover 'clos'?

#Creating a unified mask
mask = (mask_road | mask_rd |
                  mask_exit | 
                  mask_street | 
                  mask_highway | 
                  mask_hwy | 
                  mask_ramp | 
                  mask_st | 
                  mask_lane)& mask_clos | mask_close

# %%
#Separating tweets dealing with actual road closures into a separate DataFrame
data_closures = data[mask]

# %%
#Separating tweets NOT dealing with actual road closures into a separate DataFrame
data_spam = data[~mask]

# %%
data_closures.shape
# Out:
# (7738, 3)

# %%
data_closures['tweet'].isna().sum() # confirming no null values
# Out:
# 0

# %%
data_spam.shape
# Out:
# (61400, 3)

# %%
data_spam['tweet'].isna().sum() # confirming no null values
# Out:
# 0

# %%
#Introducing a label for our future positive class
data_closures['mark'] = 0

# %%
#Introducing a label for our future negative class
data_spam['mark'] = 1

# %%
data_spam['username'].value_counts()
# Out:
# NWSHouston         10185
# houstontranstar     8129
# TotalTrafficHOU     7996
# houstonpolice       7422
# HCSOTexas           4279
# ReadyHarris         4226
# us290nw_traffic     3513
# TxDOTHouston        3250
# KHOUweather         3050
# METROHouAlerts      2477
# HoustonOEM          2191
# HoustonFire         1754
# abc13weather        1729
# KPRC2WEATHER        1199
# Name: username, dtype: int64

# %%
# dropping unnecessary columns
data_closures = data_closures[['tweet','mark']]
data_spam = data_spam[['tweet','mark']]

# %%
data_spam['tweet'][100]
# Out:
# 100    Thanks to    and all of  for a great, safe wor...
# 100    IH-45 GULF Southbound At IH-610 SOUTH LOOP - S...
# 100    Radar Update: Still a window from 8 PM to 12 A...
# 100    The polls are now open until 7 pm! Plan ahead:...
# 100    Heads up! Heavy rainfall is likely Friday even...
# 100    The National Weather Service in Houston/galves...
# 100    HappeningNow: media briefing on today's severe...
# 100
# 100    Temperatures will be a few degrees warmer toni...
# Name: tweet, dtype: object

# %%
data_closures['tweet'][5]
# Out:
# 5    Crews continue to offload material from heavy ...
# 5    . and  remain closed. We hope to reopen them l...
# 5    All TxDOT offices are closed Dec. 24-26. We wa...
# 5    We have to continue staying off the roads this...
# 5    Don't forget!  will conduct its biennial inspe...
# 5    Expect streets to be closed for the  Run &amp;...
# 5    Access road on SB I-45 after Parker is closed....
# Name: tweet, dtype: object

# %% [markdown]
# ### cell below addresses the unbalanced nature between positive and negative classes

# %%
#Randomly sampling our negative tweets into a new 'Negative' DataFrame
data_negative = data_spam.sample(data_closures.shape[0])

#Concatenating our positive and negative dataframes into the final one
final_data = pd.concat([data_closures, data_negative])

#Checking the final DataFrame dimensions
final_data.shape
# Out:
# (15476, 2)

# %%
# saving as csv 
final_data.to_csv('final_data_for_modeling.csv', index=False)

# %%
## End of EDA / PreProcessing

# %% [markdown]
# # Modeling

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier,ExtraTreesClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import stop_words
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
# setting our feature and target columns
X = final['tweet'] # features
y = df_final['mark'] # target
